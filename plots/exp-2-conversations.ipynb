# %%
import pandas as pd
from network_graph import createGraph

# %%
df = pd.read_csv('../statistics/exp-2-conversations.csv')
por_paquetes = df[['Address A', 'Address B', 'Packets']]
por_bytes = df[['Address A', 'Address B', 'Bytes']]
print(por_paquetes.info())
print(por_bytes.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Address A  27 non-null     object
#  1   Address B  27 non-null     object
#  2   Packets    27 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 776.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Address A  27 non-null     object
#  1   Address B  27 non-null     object
#  2   Bytes      27 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 776.0+ bytes
# None

# %%
createGraph(por_paquetes)

# %%
createGraph(por_bytes)
